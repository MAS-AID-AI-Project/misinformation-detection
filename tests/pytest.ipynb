# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
base_path = Path('/content/drive/MyDrive/AI_Project_Course/Projects/Misinformation_Detection/repo/tests/')

# %%
# !pip install pytest

# %%
# !pip install {base_path}/../src
# Out:
# Processing ./drive/MyDrive/AI_Project_Course/Projects/Misinformation_Detection/repo/src
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.6 MB/s eta 0:00:00
# ...
#   Created wheel for misinformation_detection: filename=misinformation_detection-1.0.0-py3-none-any.whl size=20149 sha256=896eeb4a6786ef513108a3dfd2555327d881bbec1e1532b59a032b678b1a27a9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0743_oij/wheels/cc/f0/89/13edde26b8a34b0bc682c3dee76ee044232a3e8d3d1d034b80
# Successfully built misinformation_detection
# ...

# %%
# !cd {base_path}; ls eval; pytest
# Out:
# __pycache__
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/drive/MyDrive/AI_Project_Course/Projects/Misinformation_Detection/repo/tests
# plugins: langsmith-0.4.41, anyio-4.11.0, typeguard-4.4.4
# collected 0 items
#
# ============================ no tests ran in 0.05s =============================

# %% [markdown]
# # NBMerge Dummy Notebook
#
# This notebook will be used to simulate a merge conflict in nbmerge. We will simulate what happens when your teammate modifies this cell and pushes it to the remote after you already pulled changes, and you proceed to modify it after. As a result, a merge conflict will occur. Once instructed to:
#
# 1. Modify the contents of the following cell to return the sum of the cells, and modify the printed message accordingly.
# 1. Save the notebook (Ctrl+S / Cmd+S)
# 1. Return to where you left off (Step 5) in the `nbmerge_tutorial.ipynb` notebook

# %%
# PRACTICE CELL - Modify this code!
data = [1, 2, 3, 4, 5]
result = sum(data) / len(data)
print(f"The average is: {result}")

# %% [markdown]
# # Your teammate added smthn here
#
# hello!

# %%
print("hello")
